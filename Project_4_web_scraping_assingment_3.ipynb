# %%
# Importing important Libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options   
from selenium.common.exceptions import InvalidSelectorException,NoSuchElementException

# %% [markdown]
# # Ques-1 Scrape the details of most viewed videos on YouTube from Wikipedia:

# %%
#Connecting to the web server
driver=webdriver.Chrome(r"C:/Users/Akshai/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#specifying the url of the web_page
url="https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"

# %%
#openning the web page  using the web driver
driver.get(url)

# %%
#Creating list item to store the required values
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
#Extracting the rank 
rank=driver.find_elements_by_xpath("//td[1][@align='center']")

for i in rank[0:30]:
    rank=i.text
    Rank.append(rank)

# %%
#Extracting the Name of the video
Name_=driver.find_elements_by_xpath("//td[2]")

for i in Name_[0:30]:
    name=i.text
    Name.append(name)

# %%
#Extracting the artist name
art=driver.find_elements_by_xpath("//td[3]")

for i in art[0:30]:
    _art=i.text
    Artist.append(_art)

# %%
#Extracting the Uploat date
day=driver.find_elements_by_xpath("//td[5]")

for i in day[0:30]:
    up=i.text
    Upload_date.append(up)

# %%
#Extracting the Uploat date
view=driver.find_elements_by_xpath("//td[4]")

for i in view[0:30]:
    _view=i.text
    Views.append(_view)

# %%
print(len(Rank),len(Name),len(Artist),len(Views),len(Upload_date))
# Out:
# 30 30 30 30 30

# %%
Youtube_df=pd.DataFrame({})

# %%
Youtube_df['Rank']=Rank
Youtube_df['Video_Name']=Name
Youtube_df['Artist']=Artist
Youtube_df['Views_in_Billions']=Views
Youtube_df['Upload_date']=Upload_date

# %%
Youtube_df
# Out:
#    Rank                                       Video_Name  \
# 0    1.                           "Baby Shark Dance"[28]
# 1    2.                                  "Despacito"[30]
# 2    3.                               "Shape of You"[31]
# 3    4.                              "See You Again"[32]
# 4    5.   "Masha and the Bear – Recipe for Disaster"[35]
# 5    6.                       "Johny Johny Yes Papa"[36]
# 6    7.                                "Uptown Funk"[37]
# 7    8.                              "Gangnam Style"[38]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[40]
# 9   10.                                      "Sorry"[41]
# 10  11.                                  "Bath Song"[42]
# 11  12.                                      "Sugar"[43]
# 12  13.                "Phonics Song with Two Words"[44]
# 13  14.                                       "Roar"[45]
# 14  15.                          "Thinking Out Loud"[46]
# ...

# %%
driver.close()

# %% [markdown]
# # Ques-2 Scrape the details team India’s international fixtures from bcci.tv.

# %%
#Connecting to the web server
driver=webdriver.Chrome(r"C:/Users/Akshai/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#specifying the url of the web_page
url="https://www.bcci.tv"

# %%
#openning the web page  using the web driver
driver.get(url)

# %%
#creating list item to store the values
Match=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
driver.find_element_by_xpath("//ul[@class='navigation__list showMoreEnabled']/li[1]").click()

# %%
driver.find_element_by_xpath("//li[1][@class='drop-down__option  ']/a").click()

# %%
_series=driver.find_elements_by_xpath("//div[@class='fixture__format-strip']/span[2]")

for i in _series:
    _ser=i.text
    #print(_ser)
    Series.append(_ser)

# %%
_match=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/strong")

for i in _match:
    _mat=i.text
    #print(_mat)
    Match.append(_mat)

# %%
_date=driver.find_elements_by_xpath("//div[@class='fixture__description u-unskewed-text']/span[1]/strong")

for i in _date:
    _dat=i.text
    #print(_dat)
    Date.append(_dat)

# %%
_tim_=driver.find_elements_by_xpath("//div[@class='fixture__date-details']/span[2]")

for i in _tim_:
    _dat=i.text
    #print(_dat)
    Time.append(_dat)

# %%
_place=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span[1]")

for i in _place:
    _mat=i.text
    #print(_mat)
    Place.append(_mat)

# %%
print(len(Series),len(Match),len(Date),len(Time),len(Place))
# Out:
# 20 20 20 20 20

# %%
Match_df=pd.DataFrame({})

# %%
Match_df['Series']=Series
Match_df['Match']=Match
Match_df['Date']=Date
Match_df['Time']=Time
Match_df['Place']=Place

# %%
Match_df
# Out:
#                        Series     Match                     Date       Time  \
# 0   AUSTRALIA V INDIA 2020/21  1st Test   Thursday 17th December  09:30 IST
# 1   AUSTRALIA V INDIA 2020/21  2nd Test   Saturday 26th December  05:00 IST
# 2   AUSTRALIA V INDIA 2020/21  3rd Test     Thursday 7th January  05:00 IST
# 3   AUSTRALIA V INDIA 2020/21  4th Test      Friday 15th January  05:30 IST
# 4        INDIA V ENGLAND 2021  1st Test      Friday 5th February  09:30 IST
# 5        INDIA V ENGLAND 2021  2nd Test   Saturday 13th February  09:30 IST
# 6        INDIA V ENGLAND 2021  3rd Test  Wednesday 24th February  14:00 IST
# 7        INDIA V ENGLAND 2021  4th Test       Thursday 4th March  09:30 IST
# 8        INDIA V ENGLAND 2021  1st T20I        Friday 12th March  18:00 IST
# 9        INDIA V ENGLAND 2021  2nd T20I        Sunday 14th March  18:00 IST
# 10       INDIA V ENGLAND 2021  3rd T20I       Tuesday 16th March  18:00 IST
# ...

# %%
driver.close()

# %% [markdown]
# # Ques-3 Scrape the details of selenium exception from guru99.com.

# %%
#Connecting to the web server
driver=webdriver.Chrome(r"C:/Users/Akshai/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#specifying the url of the web_page
url="https://www.guru99.com/"

# %%
#opening the web page
driver.get(url)

# %%
#Clicking the selenium option in the testing column
driver.find_element_by_xpath("//ul[@class='menu']/li[3]").click()

# %%
#clicking the selenium exception column 
driver.find_element_by_xpath("//a[@title='Selenium Exception Handling (Common Exceptions List)']/strong").click()

# %%
#craeting list to store the Exception name and its description
Excep_name=[]
Excep_Description=[]

# %%
#extracting the exception name web element 
_name=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")

# %%
#checking total number of elements extracted
len(_name)
# Out:
# 42

# %%
#extracting the exception name 
for i in _name:
    _mat=i.text
    #print(_mat)
    Excep_name.append(_mat)

# %%
#extracting the exception description web element
_des=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")

# %%
#checking total number of elements extracted
len(_des)
# Out:
# 42

# %%
#extracting the exception description
for i in _des:
    _mat=i.text
    #print(_mat)
    Excep_Description.append(_mat)

# %%
#deleting the values at o position as they are not required
Excep_name.pop(0)
# Out:
# 'Exception name'

# %%
#creating the dataframe to store the record
Excep_df=pd.DataFrame({})

# %%
#storing the value in the dataframe
Excep_df['Name of the Exception']=Excep_name
Excep_df['Description']=Excep_Description

# %%
#prining the dataframe
Excep_df
# Out:
#                   Name of the Exception  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %%
driver.close()

# %% [markdown]
# # Ques-4 Scrape the details of State-wise GDP of India from statisticstime.com.

# %%
#Connecting to the web server
driver=webdriver.Chrome(r"C:/Users/Akshai/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#SPECIFYING THE URL OF THE WEB PAGE
url="http://statisticstimes.com"

# %%
#opening the webpage
driver.get(url)

# %%
#clicking the economy button 
driver.find_element_by_xpath("//div[@class='navbar']/div[2]").click()

# %%
#clicking the India in the dropdown menu appeared after performing above click
driver.find_element_by_xpath("//*[@id='top']/div[2]/div[2]/div/a[2]").click()

# %%
#selecting the option "GDP OF INDIAN STATES" IN INDIAN STATES DIVISION
driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li[1]").click()

# %%
#CREATING LIST TO STORE THE VALUES EXTRACTED BY WEB ELEMENT
RANK=[]
STATE=[]
GSDP_1=[]
GSDP_2=[]
SHARE=[]
GDP=[]

# %%
#EXTRACTING THE RANK OF THE STATES
_rank=driver.find_elements_by_xpath("//td[@class='data1']")

for i in _rank[0:33]:
    _mat=i.text
    #print(_mat)
    RANK.append(_mat)

# %%
#EXTRACTING THE STATES NAME
_state=driver.find_elements_by_xpath("//td[@class='name']")

for i in _state[0:33]:
    _mat=i.text
    #print(_mat)
    STATE.append(_mat)

# %%
#EXTRACTING GDSP(18-19)
_gdp_18_19=driver.find_elements_by_xpath("//td[3][@class='data']")

for i in _gdp_18_19[0:33]:
    _mat=i.text
    #print(_mat)
    GSDP_1.append(_mat)

# %%
#EXTARCTING GDSP(17-18)
_gdp_17_18=driver.find_elements_by_xpath("//td[@class='data sorting_1']")

for i in _gdp_17_18[0:33]:
    _mat=i.text
    #print(_mat)
    GSDP_2.append(_mat)

# %%
#EXTRACTING SHARE(2017)
share_=driver.find_elements_by_xpath("//td[5][@class='data']")
for i in share_[0:33]:
    _mat=i.text
    #print(_mat)
    SHARE.append(_mat)

# %%
#EXTRACTING GDP($_bILLION)
GDP_billion=driver.find_elements_by_xpath("//td[6][@class='data']")

for i in GDP_billion[0:33]:
    _mat=i.text
    #print(_mat)
    GDP.append(_mat)

# %%
#CHECKING WETHER ALL THE LIST IS OF SAME LENGTH BEFORE CREATING DATAFRAME
print(len(RANK),len(STATE),len(GSDP_1),len(GSDP_2),len(SHARE),len(GDP))
# Out:
# 33 33 33 33 33 33

# %%
#CREATING THE DATAFRAME
gdp_df=pd.DataFrame({})

# %%
#STORING THE VALUES IN DATAFRAME
gdp_df['Rank']=RANK
gdp_df['State']=STATE
gdp_df['GSDP_18-19']=GSDP_1
gdp_df['GSDP_17_18']=GSDP_2
gdp_df['Share_2017']=SHARE
gdp_df['GDP($_billion)']=GDP

# %%
#PRINTING THE DATAFRAME
gdp_df
# Out:
#    Rank                      State GSDP_18-19 GSDP_17_18 Share_2017  \
# 0     1                Maharashtra          -  2,411,600     14.11%
# 1     2                 Tamil Nadu  1,664,159  1,461,841      8.55%
# 2     3              Uttar Pradesh  1,542,432  1,376,324      8.05%
# 3     4                  Karnataka  1,535,224  1,350,257      7.90%
# 4     5                    Gujarat          -  1,314,680      7.69%
# 5     6                West Bengal  1,177,586    999,585      5.85%
# 6     7                  Rajasthan    929,124    835,558      4.89%
# 7     8             Andhra Pradesh    933,402    809,547      4.74%
# 8     9                  Telangana    865,688    753,811      4.41%
# 9    10             Madhya Pradesh    809,327    728,242      4.26%
# 10   11                     Kerala          -    700,532      4.10%
# 11   12                      Delhi    779,652    690,098      4.04%
# 12   13                    Haryana    707,126    626,054      3.66%
# ...

# %%
driver.close()

# %% [markdown]
# # Ques-5 Scrape the details of trending repositories on Github.com.

# %%
#Connecting to the web server
driver=webdriver.Chrome(r"C:/Users/Akshai/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#Specifying the url of the webpage
url="https://github.com"

# %%
#opening the webpage
driver.get(url)

# %%
#Clicking the Explore option in the Menubar column
driver.find_element_by_xpath("//ul[@class='d-lg-flex list-style-none']/li[4]").click()

# %%
#Clicking the selenium option in the testing column
driver.find_element_by_xpath("//ul[@class='list-style-none mb-3']/li[3]").click()

# %%
#Creating the list to store the values extracted from the web element
title=[]
description=[]
c_count=[]

# %%
title_=driver.find_elements_by_xpath("//article[@class='Box-row']/h1")

for i in title_:
    _mat=i.text
    #print(_mat)
    title.append(_mat)

# %%
w=[]

# %%
#extracting lang
lang_=driver.find_elements_by_xpath("//span[@itemprop='programmingLanguage']")

#storing the lang value in w

w.append(lang_[0].text)
w.append(lang_[1].text)
w.append(lang_[2].text)
w.append("-")
w.append(lang_[3].text)
w.append(lang_[4].text)
w.append(lang_[5].text)
w.append(lang_[6].text)
w.append(lang_[7].text)
w.append("-")
w.append("-")
w.append(lang_[8].text)
w.append(lang_[9].text)
w.append("-")
w.append(lang_[10].text)
w.append(lang_[11].text)
w.append(lang_[12].text)
w.append(lang_[13].text)
w.append(lang_[14].text)
w.append(lang_[15].text)
w.append("-")
w.append(lang_[16].text)
w.append(lang_[17].text)
w.append(lang_[18].text)
w.append(lang_[19].text)

# %%
#Extracting description
descrp_=driver.find_elements_by_xpath("//p[@class='col-9 text-gray my-1 pr-4']")

description.append("-")
description.append(descrp_[0].text)
description.append(descrp_[1].text)
description.append(descrp_[2].text)
description.append(descrp_[3].text)
description.append(descrp_[4].text)
description.append("-")
description.append(descrp_[5].text)
description.append(descrp_[6].text)
description.append(descrp_[7].text)
description.append(descrp_[8].text)
description.append(descrp_[9].text)
description.append(descrp_[10].text)
description.append(descrp_[11].text)
description.append(descrp_[12].text)
description.append(descrp_[13].text)
description.append(descrp_[14].text)
description.append(descrp_[15].text)
description.append(descrp_[16].text)
description.append(descrp_[17].text)
description.append(descrp_[18].text)
description.append(descrp_[19].text)
description.append(descrp_[20].text)
description.append(descrp_[21].text)
description.append(descrp_[22].text)

# %%
#extracting contributors count
count=driver.find_elements_by_xpath("//a[2][@class='muted-link d-inline-block mr-3']")
for i in count:
    _mat=i.text
    #print(_mat)
    c_count.append(_mat)

# %%
#checking the len og each list before creating database
print(len(title),len(w),len(description),len(c_count))
# Out:
# 25 25 25 25

# %%
#craeting dataframe
github_df=pd.DataFrame({})

github_df['Title']=title
github_df['Language_used']=w
github_df['Description']=description
github_df['Countributors_count']=c_count

github_df
# Out:
#                                                 Title     Language_used  \
# 0                                      getmeli / meli        TypeScript
# 1                                 Netflix / consoleme            Python
# 2                        rocky-linux / rockylinux.org              HTML
# 3                      labuladong / fucking-algorithm                 -
# 4           Pierian-Data / Complete-Python-3-Bootcamp  Jupyter Notebook
# 5   aapatre / Automatic-Udemy-Course-Enroller-GET-...            Python
# 6                        rocky-linux / infrastructure              HTML
# 7                                 coolsnowwolf / lede                 C
# 8                                rougier / nano-emacs        Emacs Lisp
# 9                               RobinLinus / snapdrop                 -
# 10                               Olshansk / interview                 -
# 11                                rocky-linux / rocky        JavaScript
# ...

# %%
driver.close()

# %% [markdown]
# # Ques-6 Scrape the details of top 100 songs on billiboard.com.

# %%
#Connecting to the web server
driver=webdriver.Chrome(r"C:/Users/Akshai/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#saving the url of the webpage
url="https://www.billboard.com/"

# %%
#opening the webpage
driver.get(url)

# %%
#creating list to store values extracted from web element
Name=[]
Artist=[]
LW_rank=[]
peak_rank=[]
Week=[]

# %%
#clicking on the chart menu
driver.find_element_by_xpath("//*[@id='root']/div[2]/div[2]/header/div/ul/li[1]/a").click()

# %%
#clicking the hot 1oo list
driver.find_element_by_xpath("//div[@class='charts-landing__info--view-chart-holder']").click()

# %%
#extracting the name of the song
name_=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")


for i in name_:
    _mat=i.text
    #print(_mat)
    Name.append(_mat)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6df38363d70b256a012d9dcc089e1e6e", element="77505002-562f-4589-85a4-09c15615c854")>]

# %%
#extracting the artist name
art_=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")


for i in art_:
    _mat=i.text
    #print(_mat)
    Artist.append(_mat)

# %%
#extracting the last week rank 
lw_=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")


for i in lw_:
    _mat=i.text
    #print(_mat)
    LW_rank.append(_mat)

# %%
#extracting the last peak rank 
peak_=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")


for i in peak_:
    _mat=i.text
    #print(_mat)
    peak_rank.append(_mat)

# %%
#extracting the week on board
week_=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")


for i in week_:
    _mat=i.text
    #print(_mat)
    Week.append(_mat)

# %%
#checking the len og each list before creating database
print(len(Name),len(Artist),len(LW_rank),len(peak_rank),len(Week))
# Out:
# 100 100 100 100 100

# %%
#creating dataframe
Billboard_df=pd.DataFrame({})

Billboard_df['Song_Name']=Name
Billboard_df['Artist_Name']=Artist
Billboard_df['Last_week_rank']=LW_rank
Billboard_df['Peak_rank']=peak_rank
Billboard_df['Weeks_on_board']=Week

Billboard_df
# Out:
#                             Song_Name                    Artist_Name  \
# 0                                Mood   24kGoldn Featuring iann dior
# 1     All I Want For Christmas Is You                   Mariah Carey
# 2                           Positions                  Ariana Grande
# 3   Rockin' Around The Christmas Tree                     Brenda Lee
# 4                              Dakiti        Bad Bunny & Jhay Cortez
# ..                                ...                            ...
# 95                Back To The Streets  Saweetie Featuring Jhene Aiko
# 96                      Martin & Gina                         Polo G
# 97                 Hole In The Bottle               Kelsea Ballerini
# 98                            So Done                  The Kid LAROI
# 99                            Bichota                        Karol G
#
#    Last_week_rank Peak_rank Weeks_on_board
# 0               2         1             17
# 1              14         1             40
# ...

# %%
driver.close()

# %% [markdown]
# # Ques-7

# %% [raw]
# Scrape the details of Data science recruiters from naukri.com.
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code.

# %%
#Connecting to the web server
driver=webdriver.Chrome(r"C:/Users/Akshai/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#saving the url of the webpage
url="https://www.naukri.com"

# %%
#opening the webpage
driver.get(url)

# %%
#clicking the recruiters tag
driver.find_element_by_xpath("//ul[@class='midSec menu']/li[2]").click()

# %%
driver.get("https://www.naukri.com/hr-recruiters-consultants")

# %%
#storing the input tag in variable
dd=driver.find_elements_by_css_selector("#skill > div.sWrap.lftBrd > div.inpWrap > input")

# %%
#applying for loop on dd as we dont know which input tag will take text
for d in dd:
    d.send_keys("Data Science")

# %%
driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()

# %%
#creating the list to store the value extracted from web element
Name=[]
designation=[]
Company=[]
skill=[]
location=[]

# %%
#extracting the name
name_=driver.find_elements_by_xpath("//span[@class='fl ellipsis']")

for i in name_:
    _mat=i.text
    #print(_mat)
    Name.append(_mat)

# %%
#extracting the designation
desig_=driver.find_elements_by_xpath("//span[@class='ellipsis clr']")

for i in desig_:
    _mat=i.text
    #print(_mat)
    designation.append(_mat)

# %%
#extracting the skill
skill_=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")

for i in skill_:
    _mat=i.text
    #print(_mat)
    skill.append(_mat)

# %%
#extracting the Company
comp_=driver.find_elements_by_xpath("//a[2][@class='ellipsis']")

for i in comp_:
    _mat=i.text
    #print(_mat)
    Company.append(_mat)

# %%
#extracting the Location
loca_=driver.find_elements_by_xpath("//small[@class='ellipsis']")

for i in loca_:
    _mat=i.text
    #print(_mat)
    location.append(_mat)

# %%
#checking the length of the list before importing to the dataframe
print(len(Name),len(designation),len(Company),len(skill),len(location))
# Out:
# 50 50 50 50 50

# %%
#creating database
datascience_df=pd.DataFrame({})

datascience_df['Name']=Name
datascience_df['Designation']=designation
datascience_df['Company']=Company
datascience_df['Skill']=skill
datascience_df['Loaction']=location

datascience_df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                    Talent Acquisition Executive
# 3                                    Anik Agrawal
# 4                        MARSIAN Technologies LLP
# 5                                    subhas patel
# 6                                  Jitendra Singh
# 7    Abhishek - Only Analytics Hiring - India and
# 8   Institute for Financial Management and Resear
# 9                                     Balu Ramesh
# 10                                  Asif Lucknowi
# 11                                InstaFinancials
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                                  Manisha Yadav
# 16                                   Kapil Devang
# 17                                          Rakhi
# ...

# %%
driver.close()

# %% [markdown]
# # Ques-8

# %% [raw]
# Scrape the details of Highest selling novels.
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
#Connecting to the web server
driver=webdriver.Chrome(r"C:/Users/Akshai/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#Saving the url
url="https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"

# %%
#opening the webpage
driver.get(url)

# %%
#creating the list to store the value extracted from web element
Name=[]
Author=[]
Volumes=[]
publisher=[]
genre=[]

# %%
#extracting the book name
name_=driver.find_elements_by_xpath("//td[2][@class='left']")

for i in name_:
    _mat=i.text
    #print(_mat)
    Name.append(_mat)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9f855f25140476a2569b1169b670ba53", element="f7a830d8-0233-4957-930b-c01204431023")>]

# %%
#extracting the authors name
auth_=driver.find_elements_by_xpath("//td[3][@class='left']")

for i in auth_:
    _mat=i.text
    #print(_mat)
    Author.append(_mat)

# %%
#extracting the Volumes_sold
vol_=driver.find_elements_by_xpath("//td[4][@class='left']")

for i in vol_:
    _mat=i.text
    #print(_mat)
    Volumes.append(_mat)

# %%
#extracting the Publisher name
publis_=driver.find_elements_by_xpath("//td[5][@class='left']")

for i in publis_:
    _mat=i.text
    #print(_mat)
    publisher.append(_mat)

# %%
#extracting the genre of the book
gen_=driver.find_elements_by_xpath("//td[6][@class='last left']")

for i in gen_:
    _mat=i.text
    #print(_mat)
    genre.append(_mat)

# %%
#checking the length of the list before importing to the dataframe
print(len(Name),len(Author),len(Volumes),len(publisher),len(genre))
# Out:
# 100 100 100 100 100

# %%
#creatying the dataframe and storing the values in the dataframe
Books_df=pd.DataFrame({})

Books_df['Book_Name']=Name
Books_df['Authors_Name']=Author
Books_df['Volumes_Sold']=Volumes
Books_df['Publisher']=publisher
Books_df['Genre']=genre

Books_df
# Out:
#                                             Book_Name      Authors_Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_Sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# # Ques-9

# %% [raw]
#  Scrape the details most watched tv series of all time from imdb.com.
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
#Connecting to the web server
driver=webdriver.Chrome(r"C:/Users/Akshai/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#saving the url
url="https://www.imdb.com/list/ls095964455/"

# %%
#oprning the webpage
driver.get(url)

# %%
#creating the list to store extracted elements
Name=[]
Year_Span=[]
genre=[]
run_time=[]
ratings=[]
votes=[]

# %%
#Extracting the name of the tv series
name_=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
name_[0:1]

for i in name_:
    _mat=i.text
    #print(_mat)
    Name.append(_mat)

# %%
#extracting the year span
y_s=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")

for i in y_s:
    _mat=i.text
    #print(_mat)
    Year_Span.append(_mat)

# %%
#extracting the genere of the tv series
gen=driver.find_elements_by_xpath("//span[@class='genre']")

for i in gen:
    _mat=i.text
    #print(_mat)
    genre.append(_mat)

# %%
#extracting the runtime of the tv series
r_time=driver.find_elements_by_xpath("//span[@class='runtime']")

for i in r_time:
    _mat=i.text
    #print(_mat)
    run_time.append(_mat)

# %%
#extracting the ratings of the tv series
rate=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]")

for i in rate:
    _mat=i.text
    #print(_mat)
    ratings.append(_mat)

# %%
#extracting the no of votes
vote_=driver.find_elements_by_xpath("//span[@name='nv']")

for i in vote_:
    _mat=i.text
    #print(_mat)
    votes.append(_mat)

# %%
#checking the length of the list before importing to the dataframe
print(len(Name),len(Year_Span),len(run_time),len(ratings),len(genre),len(votes))
# Out:
# 100 100 100 100 100 100

# %%
#creating dataframe and storing the values
tv_series_df=pd.DataFrame({})

tv_series_df['Name']=Name
tv_series_df['Year_Span']=Year_Span
tv_series_df['Genre']=genre
tv_series_df['Run_Time']=run_time
tv_series_df['Ratings']=ratings
tv_series_df['Votes']=votes

tv_series_df
# Out:
#                               Name    Year_Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead     (2010– )   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series     (2015– )      Crime, Drama, Horror
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_Time Ratings      Votes
# 0    57 min     9.3  1,738,442
# ...

# %%
driver.close()

# %% [markdown]
# # Ques-10

# %% [raw]
# Details of Datasets from UCI machine learning repositories.
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
#Connecting to the web server
driver=webdriver.Chrome(r"C:/Users/Akshai/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#saving the url
url="https://archive.ics.uci.edu/ml/index.php"

# %%
#oprning the webpage
driver.get(url)

# %%
#creating the list to store extracted elements
Name=[]
Type=[]
Task=[]
Attribute=[]
no_of_instances=[]
no_of_attributes=[]
year=[]

# %%
#clicking the option view all datasets
driver.find_element_by_xpath("//a[@href='datasets.php']").click()

# %%
#Extracting the name of the dataset
name_=driver.find_elements_by_xpath("//p[@class='normal']/b/a")
name_[0:1]


for i in name_:
    _mat=i.text
    #print(_mat)
    Name.append(_mat)

# %%
#Extracting the data type of the dataset
type_=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p")


for i in type_:
    _mat=i.text
    #print(_mat)
    Type.append(_mat)

# %%
#Extracting the task to be performed on the dataset
task_=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p")


for i in task_:
    _mat=i.text
    #print(_mat)
    Task.append(_mat)

# %%
#Extracting the Attributes of the dataset
Att_=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p")


for i in Att_:
    _mat=i.text
    #print(_mat)
    Attribute.append(_mat)

# %%
#Extracting the no_instances present in the dataset
noi_=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p")


for i in noi_:
    _mat=i.text
    #print(_mat)
    no_of_instances.append(_mat)

# %%
#Extracting the no_of_attributes present in the dataset
noa_=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p")


for i in noa_:
    _mat=i.text
    #print(_mat)
    no_of_attributes.append(_mat)

# %%
#Extracting the year in which dataset was uploaded
year_=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p")


for i in year_:
    _mat=i.text
    #print(_mat)
    year.append(_mat)

# %%
#checking the length of the list before importing to the dataframe
print(len(Name),len(Type),len(Task),len(Attribute),len(no_of_instances),len(no_of_attributes),len(year))
# Out:
# 559 559 559 559 559 559 559

# %%
#creating tha database to store extracted values
uci_df=pd.DataFrame({})

uci_df['Data_set_name']=Name
uci_df['Data_types']=Type
uci_df['Default_task']=Task
uci_df['Attribute_Type']=Attribute
uci_df['no_of_instances']=no_of_instances
uci_df['no_of_attributes']=no_of_attributes
uci_df['Year']=year

uci_df
# Out:
#                                          Data_set_name     Data_types  \
# 0                                              Abalone  Multivariate
# 1                                                Adult  Multivariate
# 2                                            Annealing  Multivariate
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia  Multivariate
# ..                                                 ...            ...
# 554          IIWA14-R820-Gazebo-Dataset-10Trajectories
# 555                     Guitar Chords finger positions          Text
# 556               Russian Corpus of Biographical Texts          Text
# 557                                        Codon usage  Multivariate
# 558  Intelligent Media Accelerometer and Gyroscope ...   Time-Series
#
#                     Default_task               Attribute_Type no_of_instances  \
# 0                Classification   Categorical, Integer, Real            4177
# ...

# %%
driver.close()
